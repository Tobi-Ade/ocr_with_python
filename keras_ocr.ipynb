# %%
import keras_ocr as kcr

# %%
pipeline = kcr.pipeline.Pipeline()
# Out:
# Looking for /home/ubuntu/.keras-ocr/craft_mlt_25k.h5
# Downloading /home/ubuntu/.keras-ocr/craft_mlt_25k.h5
# Looking for /home/ubuntu/.keras-ocr/crnn_kurapan.h5
# Downloading /home/ubuntu/.keras-ocr/crnn_kurapan.h5

# %%
images = [ kcr.tools.read(image) for image in [
                                            "./images/download.png",
                                            "./images/Iconberg-Snapper-Frame-300x457.jpg",
                                            "./images/images.jfif"
                                    ]
]

# %%
pred_groups = pipeline.recognize(images)
# Out:
# 2023-08-22 11:22:22.983926: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 459076608 exceeds 10% of free system memory.
# 2023-08-22 11:22:23.255868: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 459076608 exceeds 10% of free system memory.
# 2023-08-22 11:22:23.472366: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 459076608 exceeds 10% of free system memory.
# 2023-08-22 11:22:24.180187: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 459076608 exceeds 10% of free system memory.
# 1/1 [==============================] - 8s 8s/step
# 3/3 [==============================] - 6s 937ms/step

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, pred_groups):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
